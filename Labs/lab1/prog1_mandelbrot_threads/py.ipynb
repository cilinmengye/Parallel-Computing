# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
threadNum = np.array([k for k in range(2, 9)])
speedUp = np.array([2.25, 1.65, 0.71, 2.28, 3.15, 2.80, 2.82])
plt.plot(threadNum, speedUp)
plt.show()
