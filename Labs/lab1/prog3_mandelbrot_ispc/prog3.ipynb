# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

taskNums = np.array([1, 2, 4, 8, 16, 32, 40, 48, 56, 64])
seedups = np.array([5.03, 9.37, 6.90, 9.33, 13.39, 22.67, 28.47, 34.56, 37.79, 42.86])

plt.plot(taskNums, seedups)
plt.xlabel("taskNums")
plt.ylabel("seedups")
plt.title("VIEW 1")
plt.show()
