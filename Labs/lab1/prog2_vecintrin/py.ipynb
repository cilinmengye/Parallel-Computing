# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

vector_width = np.array([2, 4, 8, 16])
utilization = np.array([89.8, 87.8, 86.7, 86.2])

plt.plot(vector_width, utilization)
plt.xlabel("vector_width")
plt.ylabel("utilization")
plt.title("VIEW 1")
plt.show()
